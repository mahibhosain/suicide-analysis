# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview
# Our goal was to analyze the correlation between the economic status of specific countries throughout multiple years compared to their national suicide rates. We chose countries from different levels of economic development to analyze and identify trends in relation to the suicide rate and economic position. To measure and categorize socioeconomic status, we used GDP to determine whether certain countries have a higher position than others.

# %% [markdown]
# # Names
# Jennifer Sandoval<br>
# Maxwell Takeda<br>
# Wye Mun Chin<br>
# Mahib Hosain<br>
# Jinghan Zhang

# %% [markdown]
# # Group Member IDs
# A10869288<br>
# A13868249<br>
# A14002736<br>
# A92025178<br>
# A14905362

# %% [markdown]
# # Research Question
# Does the economic status of a country influence its suicide rate? Specifically, analyzing the rate of suicide compared to the GDP per year for different countries.<br>
# HDI vs. Suicide for 10 countries<br>
# Human Development Index (HDI) is a statistic used to compare and rank countries by their level of human development. Factors such as income, health, and education is measured in HDI. We attempt to observe if the HDI of a country is indicative of the number of suicides in a country.<br>
# GDP vs. Suicide Rate<br>
# Gross Domestic Product (GDP) is a statistic that measures the total value of a country's goods and services. Frequently, GDP is also used as an indicator of how well a country's economy is doing and whether it is growing. Similarly to HDI, we are trying to see if the rise (or decline) in GDP correlates to the number of suicides a country has over time.

# %% [markdown]
# # Background and prior work
# For this project, our group was interested in analyzing the level of correlation between the standard of living and suicide rates. Before deciding upon a hypothesis, we began researching to find relevant datasets to use and documents that could assist in formulating a strong hypothesis. <br><br>
#
# To find relevant documents, we used Google Scholar which provided case studies and scientific articles. The article, “Economic growth and suicide rate changes: A case in China from 1982 to 2005”, by J. Zhang, et al. analyzed and described the relationship between economic growth and the suicide rate in China from 1982 to 2005. For this study, one of the important factors that J. Zhang et al. analyzed for measuring economic growth was GDP in China. GDP is also a data measurement that we are using in our data analysis, so this article was especially relevant for our background research, and a strong predictor for our hypothesis. In this study, the results illustrated that economic growth correlated to a decrease in the suicide rate.<br><br>
#
# Our group then searched for sources that measured the impact of a decline in economic growth in relation to suicide rates. This information, along with the results from the case study in China, could help solidify our prediction and allow us to create a well-informed hypothesis. The article, “Impact of 2008 global economic crisis on suicide: time trend study in 54 countries” by Shu-Sen Chang et al. analyzed the economic crisis from 2008 in relation to the suicide rate in  54 different countries. The results were not as useful as the case study in China, because the suicide rate was more affected by an increase in unemployment rather than the average economic status of the country. Nonetheless, this result helped us formulate a strong hypothesis about the relationship between a country’s economic status and the national suicide rate.<br><br>
#
# 1) https://www.sciencedirect.com/science/article/pii/S0924933809001370<br>
# 2) https://www.bmj.com/content/347/bmj.f5239.short

# %% [markdown]
# # Hypothesis
# We hypothesize that there will be a strong negative correlation between socioeconomic status and suicide rate. Since a higher standard of living will correlate to a lower suicide rate, and a more content and satisfied population.

# %% [markdown]
# # Dataset(s)
# Dataset Name: Suicide Rates Overview 1985 to 2016 <br>
# Link to the dataset: https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016#master.csv<br>
# Number of observations: 27.8k<br><br>
# This dataset includes social and economic information from different country and compares it to the suicide rate by age groups, and generations. The observations are by year, from 1985 to 2016.

# %% [markdown]
# # Setup

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

#
# 21                    769           Silent
# 22                    769     Generation X
# 23                    769     Generation X
# 24                    833  G.I. Generation
# 25                    833          Boomers
# 26                    833           Silent
# 27                    833  G.I. Generation
# 28                    833     Generation X
# 29                    833           Silent
# ...                   ...              ...
# 27790                1964       Millenials
# 27791                1964     Generation X
# 27792                1964     Generation Z
# 27793                1964          Boomers
# 27794                1964           Silent
# 27795                1964     Generation Z
# 27796                2150     Generation X
# 27797                2150       Millenials
# 27798                2150       Millenials
# 27799                2150       Millenials
# 27800                2150          Boomers
# 27801                2150           Silent
# 27802                2150       Millenials
# 27803                2150     Generation X
# 27804                2150           Silent
# 27805                2150     Generation Z
# 27806                2150          Boomers
# 27807                2150     Generation Z
# 27808                2309     Generation X
# 27809                2309       Millenials
# 27810                2309       Millenials
# 27811                2309          Boomers
# 27812                2309       Millenials
# 27813                2309           Silent
# 27814                2309       Millenials
# 27815                2309     Generation X
# 27816                2309           Silent
# 27817                2309     Generation Z
# 27818                2309     Generation Z
# 27819                2309          Boomers
#
# [27820 rows x 12 columns]

# %%
data["country"].unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Republic of Korea', 'Romania', 'Russian Federation',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and Grenadines', 'San Marino', 'Serbia',
#        'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa',
#        'Spain', 'Sri Lanka', 'Suriname', 'Sweden', 'Switzerland',
#        'Thailand', 'Trinidad and Tobago', 'Turkey', 'Turkmenistan',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan'], dtype=object)

# %%
new_df = data.dropna(subset=['HDI for year'], inplace=True)
print(new_df)
# Out:
# None

# %% [markdown]
# We attempt to find a correlation between the HDI of various countries and its suicide rate (over time).
# First, drop unnecessary columns and rows that are not of interest.

# %%
hdi_suicide = data.copy(deep=True)
hdi_suicide = hdi_suicide.drop(['sex', 'age', 'suicides_no', 'population', 'generation'], axis = 1)
hdi_suicide = hdi_suicide.drop(hdi_suicide.columns[5], axis=1)
hdi_suicide = hdi_suicide.drop(hdi_suicide.columns[5], axis=1)
hdi_suicide.set_index("country", inplace = True)
hdi_suicide.head()
hdi_suicide = hdi_suicide.loc[['Sweden', 'United States', 'Japan', 'Thailand', 'Mexico', 'Brazil', 'Maritius', 'Albania', 'Kyrgysztan', 'Luxembourg']]
hdi_suicide.dropna(how="any")
hdi_suicide
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   import sys
#               year  suicides/100k pop    country-year  HDI for year
# country
# Sweden      1990.0              55.07      Sweden1990         0.815
# Sweden      1990.0              35.96      Sweden1990         0.815
# Sweden      1990.0              28.96      Sweden1990         0.815
# Sweden      1990.0              25.88      Sweden1990         0.815
# Sweden      1990.0              15.61      Sweden1990         0.815
# Sweden      1990.0              14.90      Sweden1990         0.815
# Sweden      1990.0              14.66      Sweden1990         0.815
# Sweden      1990.0              13.80      Sweden1990         0.815
# Sweden      1990.0              10.96      Sweden1990         0.815
# Sweden      1990.0               5.25      Sweden1990         0.815
# Sweden      1990.0               0.79      Sweden1990         0.815
# Sweden      1990.0               0.21      Sweden1990         0.815
# Sweden      1995.0              42.86      Sweden1995         0.856
# Sweden      1995.0              30.07      Sweden1995         0.856
# Sweden      1995.0              29.32      Sweden1995         0.856
# Sweden      1995.0              20.91      Sweden1995         0.856
# Sweden      1995.0              17.19      Sweden1995         0.856
# Sweden      1995.0              13.70      Sweden1995         0.856
# Sweden      1995.0              13.44      Sweden1995         0.856
# Sweden      1995.0              11.85      Sweden1995         0.856
# Sweden      1995.0               6.40      Sweden1995         0.856
# Sweden      1995.0               5.24      Sweden1995         0.856
# Sweden      1995.0               0.55      Sweden1995         0.856
# Sweden      1995.0               0.19      Sweden1995         0.856
# Sweden      2000.0              42.22      Sweden2000         0.897
# Sweden      2000.0              25.92      Sweden2000         0.897
# Sweden      2000.0              22.17      Sweden2000         0.897
# Sweden      2000.0              18.20      Sweden2000         0.897
# Sweden      2000.0              12.01      Sweden2000         0.897
# Sweden      2000.0              11.10      Sweden2000         0.897
# ...            ...                ...             ...           ...
# Luxembourg  2012.0               6.20  Luxembourg2012         0.888
# Luxembourg  2012.0               6.08  Luxembourg2012         0.888
# Luxembourg  2012.0               3.18  Luxembourg2012         0.888
# Luxembourg  2012.0               2.59  Luxembourg2012         0.888
# Luxembourg  2012.0               0.00  Luxembourg2012         0.888
# Luxembourg  2012.0               0.00  Luxembourg2012         0.888
# Luxembourg  2013.0              21.36  Luxembourg2013         0.890
# Luxembourg  2013.0              17.90  Luxembourg2013         0.890
# Luxembourg  2013.0              15.76  Luxembourg2013         0.890
# Luxembourg  2013.0              11.58  Luxembourg2013         0.890
# Luxembourg  2013.0               9.05  Luxembourg2013         0.890
# Luxembourg  2013.0               5.93  Luxembourg2013         0.890
# Luxembourg  2013.0               5.04  Luxembourg2013         0.890
# Luxembourg  2013.0               4.86  Luxembourg2013         0.890
# Luxembourg  2013.0               0.00  Luxembourg2013         0.890
# Luxembourg  2013.0               0.00  Luxembourg2013         0.890
# Luxembourg  2013.0               0.00  Luxembourg2013         0.890
# Luxembourg  2013.0               0.00  Luxembourg2013         0.890
# Luxembourg  2014.0              34.42  Luxembourg2014         0.892
# Luxembourg  2014.0              27.50  Luxembourg2014         0.892
# Luxembourg  2014.0              22.67  Luxembourg2014         0.892
# Luxembourg  2014.0              16.89  Luxembourg2014         0.892
# Luxembourg  2014.0              13.23  Luxembourg2014         0.892
# Luxembourg  2014.0               9.57  Luxembourg2014         0.892
# Luxembourg  2014.0               6.15  Luxembourg2014         0.892
# Luxembourg  2014.0               5.84  Luxembourg2014         0.892
# Luxembourg  2014.0               4.89  Luxembourg2014         0.892
# Luxembourg  2014.0               3.57  Luxembourg2014         0.892
# Luxembourg  2014.0               3.15  Luxembourg2014         0.892
# Luxembourg  2014.0               0.00  Luxembourg2014         0.892
#
# [878 rows x 4 columns]

# %% [markdown]
# attempting the second question of gdp & suicide rate for all countries (correlation + trends)

# %%
#making a dataframe out of the csv data
data2 = pd.read_csv("suicide_statistics.csv")
df2 = pd.DataFrame(data2)
df2.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
#drop all irrelevant columns
df2_drop = df2.drop(['HDI for year', 'generation'],axis=1)

#rename columns and drop rows that don't have our var of interest i.e. gdp per year
df2_drop.columns = ['country', 'year', 'sex', 'age', 'suicides_no', 'population', 'suicides/100k','country-year','gdp_year','gdp_capita']
df2_drop = df2_drop.dropna(axis=0, subset=['gdp_year'])

df2_drop.head()
# Out:
#    country  year     sex          age  suicides_no  population  suicides/100k  \
# 0  Albania  1987    male  15-24 years           21      312900           6.71
# 1  Albania  1987    male  35-54 years           16      308000           5.19
# 2  Albania  1987  female  15-24 years           14      289700           4.83
# 3  Albania  1987    male    75+ years            1       21800           4.59
# 4  Albania  1987    male  25-34 years            9      274300           3.28
#
#   country-year       gdp_year  gdp_capita
# 0  Albania1987  2,156,624,900         796
# 1  Albania1987  2,156,624,900         796
# 2  Albania1987  2,156,624,900         796
# 3  Albania1987  2,156,624,900         796
# 4  Albania1987  2,156,624,900         796

# %%
#find gdp for each country in each year
df2_gdp = df2_drop[['country-year','gdp_year']]
df2_gdp = df2_gdp.drop_duplicates()
df2_gdp = df2_gdp.reset_index()

#function that checks the gdp for a certain country in a certain year
def get_GDP(str_in) :
    print(str_in)
    filter = df2_gdp["country-year"] == str_in
    res = df2_gdp.where(filter).dropna()
    if (res.empty):
        return -1
    else:
        print(res)
        return int(res['gdp_year'].str.replace(',',''))

#find suicide rate for each country by totalling # suicides, dividing over total population then over 100k for better visualization
df2_suiciderate = df2_drop.groupby(['country','year']).sum()
df2_suiciderate['suicide/100k'] = df2_suiciderate['suicides_no'] / df2_suiciderate['population'] * 100000
df2_suicide_reset = df2_suiciderate.reset_index()

#adding the country-year, to help find gdp for that country and year and adding both of these to the df
country_year = []
gdp_year = []

for row in df2_suicide_reset.itertuples():
    cy = row[1] + str(row[2])
    print(cy)
    country_year.append(cy)
    gdp = get_GDP(cy)
    gdp_year.append(gdp)
    
df2_suicide_reset['country-year'] = country_year
df2_suicide_reset['gdp_year'] = gdp_year

#dropping unnecessary cols
df2_suicide_reset = df2_suicide_reset.drop(['gdp_capita','suicides/100k'],axis=1)
df2_suicide_reset.head()
# Out:
# Albania1987
# Albania1987
#    index country-year       gdp_year
# 0    0.0  Albania1987  2,156,624,900
# Albania1988
# Albania1988
#    index country-year       gdp_year
# 1   12.0  Albania1988  2,126,000,000
# Albania1989
# Albania1989
#    index country-year       gdp_year
# 2   24.0  Albania1989  2,335,124,988
# Albania1992
# Albania1992
#    index country-year     gdp_year
# 3   36.0  Albania1992  709,452,584
# Albania1993
# Albania1993
#    index country-year       gdp_year
# 4   48.0  Albania1993  1,228,071,038
# Albania1994
# Albania1994
#    index country-year       gdp_year
# 5   60.0  Albania1994  1,985,673,798
# Albania1995
# Albania1995
#    index country-year       gdp_year
# 6   72.0  Albania1995  2,424,499,009
# Albania1996
# Albania1996
#    index country-year       gdp_year
# 7   84.0  Albania1996  3,314,898,292
# Albania1997
# Albania1997
#    index country-year       gdp_year
# 8   96.0  Albania1997  2,359,903,108
# Albania1998
# Albania1998
#    index country-year       gdp_year
# 9  108.0  Albania1998  2,707,123,772
# Albania1999
# Albania1999
#     index country-year       gdp_year
# 10  120.0  Albania1999  3,414,760,915
# Albania2000
# Albania2000
#     index country-year       gdp_year
# 11  132.0  Albania2000  3,632,043,908
# Albania2001
# Albania2001
#     index country-year       gdp_year
# 12  144.0  Albania2001  4,060,758,804
# Albania2002
# Albania2002
#     index country-year       gdp_year
# 13  156.0  Albania2002  4,435,078,648
# Albania2003
# Albania2003
#     index country-year       gdp_year
# 14  168.0  Albania2003  5,746,945,913
# Albania2004
# Albania2004
#     index country-year       gdp_year
# 15  180.0  Albania2004  7,314,865,176
# Albania2005
# Albania2005
#     index country-year       gdp_year
# 16  192.0  Albania2005  8,158,548,717
# Albania2006
# Albania2006
#     index country-year       gdp_year
# 17  204.0  Albania2006  8,992,642,349
# Albania2007
# Albania2007
#     index country-year        gdp_year
# 18  216.0  Albania2007  10,701,011,897
# Albania2008
# Albania2008
#     index country-year        gdp_year
# 19  228.0  Albania2008  12,881,352,688
# Albania2009
# Albania2009
#     index country-year        gdp_year
# 20  240.0  Albania2009  12,044,212,904
# Albania2010
# Albania2010
#     index country-year        gdp_year
# 21  252.0  Albania2010  11,926,953,259
# Antigua and Barbuda1985
# Antigua and Barbuda1985
#     index             country-year     gdp_year
# 22  264.0  Antigua and Barbuda1985  240,923,926
# Antigua and Barbuda1986
# Antigua and Barbuda1986
#     index             country-year     gdp_year
# 23  276.0  Antigua and Barbuda1986  290,440,148
# Antigua and Barbuda1987
# Antigua and Barbuda1987
#     index             country-year     gdp_year
# 24  288.0  Antigua and Barbuda1987  337,174,852
# Antigua and Barbuda1988
# Antigua and Barbuda1988
#     index             country-year     gdp_year
# 25  300.0  Antigua and Barbuda1988  398,637,741
# Antigua and Barbuda1989
# Antigua and Barbuda1989
#     index             country-year     gdp_year
# 26  312.0  Antigua and Barbuda1989  438,794,778
# Antigua and Barbuda1990
# Antigua and Barbuda1990
#     index             country-year     gdp_year
# 27  324.0  Antigua and Barbuda1990  459,469,074
# Antigua and Barbuda1991
# Antigua and Barbuda1991
#     index             country-year     gdp_year
# 28  336.0  Antigua and Barbuda1991  481,706,333
# Antigua and Barbuda1992
# Antigua and Barbuda1992
#     index             country-year     gdp_year
# 29  348.0  Antigua and Barbuda1992  499,281,148
# Antigua and Barbuda1993
# Antigua and Barbuda1993
#     index             country-year     gdp_year
# 30  360.0  Antigua and Barbuda1993  535,172,778
# Antigua and Barbuda1994
# Antigua and Barbuda1994
#     index             country-year     gdp_year
# 31  372.0  Antigua and Barbuda1994  589,429,593
# Antigua and Barbuda1995
# Antigua and Barbuda1995
#     index             country-year     gdp_year
# 32  384.0  Antigua and Barbuda1995  577,280,741
# Antigua and Barbuda1998
# Antigua and Barbuda1998
#     index             country-year     gdp_year
# 33  396.0  Antigua and Barbuda1998  727,860,593
# Antigua and Barbuda1999
# Antigua and Barbuda1999
#     index             country-year     gdp_year
# 34  408.0  Antigua and Barbuda1999  766,198,926
# Antigua and Barbuda2000
# Antigua and Barbuda2000
#     index             country-year     gdp_year
# 35  420.0  Antigua and Barbuda2000  830,158,778
#      index country-year       gdp_year
# 89  1068.0  Armenia1999  1,845,482,181
# Armenia2000
# Armenia2000
#      index country-year       gdp_year
# 90  1080.0  Armenia2000  1,911,563,665
# Armenia2001
# Armenia2001
#      index country-year       gdp_year
# 91  1092.0  Armenia2001  2,118,467,913
# Armenia2002
# Armenia2002
#      index country-year       gdp_year
# 92  1104.0  Armenia2002  2,376,335,048
# Armenia2003
# Armenia2003
#      index country-year       gdp_year
# 93  1116.0  Armenia2003  2,807,061,009
# Armenia2006
# Armenia2006
#      index country-year       gdp_year
# 94  1128.0  Armenia2006  6,384,451,606
# Armenia2007
# Armenia2007
#      index country-year       gdp_year
# 95  1140.0  Armenia2007  9,206,301,700
# Armenia2008
# Armenia2008
#      index country-year        gdp_year
# 96  1152.0  Armenia2008  11,662,040,714
# Armenia2009
# Armenia2009
#      index country-year       gdp_year
# 97  1164.0  Armenia2009  8,647,936,748
# Armenia2010
# Armenia2010
#      index country-year       gdp_year
# 98  1176.0  Armenia2010  9,260,284,938
# Armenia2011
# Armenia2011
#      index country-year        gdp_year
# 99  1188.0  Armenia2011  10,142,111,334
# Armenia2012
# Armenia2012
#       index country-year        gdp_year
# 100  1200.0  Armenia2012  10,619,320,049
# Armenia2013
# Armenia2013
#       index country-year        gdp_year
# 101  1212.0  Armenia2013  11,121,465,767
# Armenia2014
# Armenia2014
#       index country-year        gdp_year
# 102  1224.0  Armenia2014  11,609,512,940
# Armenia2015
# Armenia2015
#       index country-year        gdp_year
# 103  1236.0  Armenia2015  10,553,337,673
# Armenia2016
# Armenia2016
#       index country-year        gdp_year
# 104  1248.0  Armenia2016  10,546,135,160
# Aruba1995
# Aruba1995
#       index country-year       gdp_year
# 105  1258.0    Aruba1995  1,320,670,391
# Aruba1999
# Aruba1999
#       index country-year       gdp_year
# 106  1270.0    Aruba1999  1,722,798,883
# Aruba2000
# Aruba2000
#       index country-year       gdp_year
# 107  1282.0    Aruba2000  1,873,452,514
# Aruba2001
# Aruba2001
#       index country-year       gdp_year
# 108  1294.0    Aruba2001  1,920,262,570
# Aruba2002
# Aruba2002
#       index country-year       gdp_year
# 109  1306.0    Aruba2002  1,941,094,972
# Aruba2003
# Aruba2003
#       index country-year       gdp_year
# 110  1318.0    Aruba2003  2,021,301,676
# Aruba2004
# Aruba2004
#       index country-year       gdp_year
# 111  1330.0    Aruba2004  2,228,279,330
# Aruba2005
# Aruba2005
#       index country-year       gdp_year
# 112  1342.0    Aruba2005  2,331,005,587
# Aruba2006
# Aruba2006
#       index country-year       gdp_year
# 113  1354.0    Aruba2006  2,421,474,860
# Aruba2007
# Aruba2007
#       index country-year       gdp_year
# 114  1366.0    Aruba2007  2,623,726,257
# Aruba2008
# Aruba2008
#       index country-year       gdp_year
# 115  1378.0    Aruba2008  2,791,960,894
# Aruba2009
# Aruba2009
#       index country-year       gdp_year
# 116  1390.0    Aruba2009  2,498,932,961
# Aruba2010
# Aruba2010
#       index country-year       gdp_year
# 117  1402.0    Aruba2010  2,467,703,911
# Aruba2011
# Aruba2011
# Australia2015
#       index   country-year           gdp_year
# 148  1774.0  Australia2015  1,349,034,029,453
# Austria1985
# Austria1985
#       index country-year        gdp_year
# 149  1786.0  Austria1985  69,386,774,475
# Austria1986
# Austria1986
#       index country-year        gdp_year
# 150  1798.0  Austria1986  99,036,165,210
# Austria1987
# Austria1987
#       index country-year         gdp_year
# 151  1810.0  Austria1987  124,168,442,860
# Austria1988
# Austria1988
#       index country-year         gdp_year
# 152  1822.0  Austria1988  133,339,397,080
# Austria1989
# Austria1989
#       index country-year         gdp_year
# 153  1834.0  Austria1989  133,105,805,928
# Austria1990
# Austria1990
#       index country-year         gdp_year
# 154  1846.0  Austria1990  166,463,386,663
# Austria1991
# Austria1991
#       index country-year         gdp_year
# 155  1858.0  Austria1991  173,794,177,725
# Austria1992
# Austria1992
#       index country-year         gdp_year
# 156  1870.0  Austria1992  195,078,126,346
# Austria1993
# Austria1993
#       index country-year         gdp_year
# 157  1882.0  Austria1993  190,379,720,927
# Austria1994
# Austria1994
#       index country-year         gdp_year
# 158  1894.0  Austria1994  203,535,242,742
# Austria1995
# Austria1995
#       index country-year         gdp_year
# 159  1906.0  Austria1995  241,038,283,063
# Austria1996
# Austria1996
#       index country-year         gdp_year
# 160  1918.0  Austria1996  237,250,948,791
# Austria1997
# Austria1997
#       index country-year         gdp_year
# 161  1930.0  Austria1997  212,790,348,405
# Austria1998
# Austria1998
#       index country-year         gdp_year
# 162  1942.0  Austria1998  218,259,904,402
# Austria1999
# Austria1999
#       index country-year         gdp_year
# 163  1954.0  Austria1999  217,185,787,343
# Austria2000
# Austria2000
#       index country-year         gdp_year
# 164  1966.0  Austria2000  196,799,778,883
# Austria2001
# Austria2001
#       index country-year         gdp_year
# 165  1978.0  Austria2001  197,337,879,195
# Austria2002
# Austria2002
#       index country-year         gdp_year
# 166  1990.0  Austria2002  213,377,771,504
# Austria2003
# Austria2003
#       index country-year         gdp_year
# 167  2002.0  Austria2003  261,695,778,781
# Austria2004
# Austria2004
#       index country-year         gdp_year
# 168  2014.0  Austria2004  300,904,221,505
# Austria2005
# Austria2005
#       index country-year         gdp_year
# 169  2026.0  Austria2005  315,974,418,605
# Austria2006
# Austria2006
#       index country-year         gdp_year
# 170  2038.0  Austria2006  335,998,557,270
# Austria2007
# Austria2007
#       index country-year         gdp_year
# 171  2050.0  Austria2007  388,691,445,387
# Austria2008
# Austria2008
#       index country-year         gdp_year
# 172  2062.0  Austria2008  430,294,287,388
# Austria2009
# Austria2009
#       index country-year         gdp_year
# 173  2074.0  Austria2009  400,172,297,861
# Austria2010
# Austria2010
#       index country-year         gdp_year
# 174  2086.0  Austria2010  391,892,746,545
# Austria2011
# Austria2011
#       index country-year         gdp_year
# 175  2098.0  Austria2011  431,120,310,089
# Austria2012
# Austria2012
#       index country-year         gdp_year
# 176  2110.0  Austria2012  409,425,234,155
# Austria2013
# Austria2013
#       index country-year         gdp_year
# 177  2122.0  Austria2013  430,068,712,972
# Austria2014
# Austria2014
#       index country-year         gdp_year
# 178  2134.0  Austria2014  441,885,415,806
# Austria2015
# Austria2015
#       index country-year         gdp_year
# 179  2146.0  Austria2015  382,065,930,308
# Austria2016
# Austria2016
#       index country-year         gdp_year
# 180  2158.0  Austria2016  390,799,991,147
# Azerbaijan1990
# Azerbaijan1990
#       index    country-year       gdp_year
# 181  2168.0  Azerbaijan1990  8,858,006,036
# Azerbaijan1991
# Azerbaijan1991
#       index    country-year       gdp_year
# 182  2180.0  Azerbaijan1991  8,792,365,811
# Azerbaijan1992
# Azerbaijan1992
#       index    country-year       gdp_year
# 183  2192.0  Azerbaijan1992  4,991,350,458
# Azerbaijan1993
# Azerbaijan1993
#       index    country-year       gdp_year
# 184  2204.0  Azerbaijan1993  3,973,027,397
# Azerbaijan1994
# Azerbaijan1994
#       index    country-year       gdp_year
# 185  2216.0  Azerbaijan1994  3,313,739,674
# Azerbaijan1995
# Azerbaijan1995
#       index    country-year       gdp_year
# 186  2228.0  Azerbaijan1995  3,052,467,522
# Azerbaijan1996
# Azerbaijan1996
#       index    country-year       gdp_year
# 187  2240.0  Azerbaijan1996  3,176,749,593
# Azerbaijan1997
# Azerbaijan1997
#       index    country-year       gdp_year
# 188  2252.0  Azerbaijan1997  3,962,710,163
# Azerbaijan1998
# Azerbaijan1998
#       index    country-year       gdp_year
# 189  2264.0  Azerbaijan1998  4,446,396,218
# Azerbaijan1999
# Azerbaijan1999
#       index    country-year       gdp_year
# 190  2276.0  Azerbaijan1999  4,581,222,442
# Azerbaijan2000
# Azerbaijan2000
#       index    country-year       gdp_year
# 191  2288.0  Azerbaijan2000  5,272,617,196
# Azerbaijan2001
# Azerbaijan2001
#       index    country-year       gdp_year
# 192  2300.0  Azerbaijan2001  5,707,720,391
# Azerbaijan2002
# Azerbaijan2002
#       index    country-year       gdp_year
# 193  2312.0  Azerbaijan2002  6,235,795,104
# Azerbaijan2003
# Azerbaijan2003
#       index    country-year       gdp_year
# 194  2324.0  Azerbaijan2003  7,276,013,032
# Azerbaijan2004
# Azerbaijan2004
#       index    country-year       gdp_year
# 195  2336.0  Azerbaijan2004  8,680,472,169
# Azerbaijan2007
# Azerbaijan2007
#       index    country-year        gdp_year
# 196  2348.0  Azerbaijan2007  33,050,343,783
# Bahamas1985
# Bahamas1985
#       index country-year       gdp_year
# 197  2360.0  Bahamas1985  2,320,699,900
# Bahamas1987
# Bahamas1987
#       index country-year       gdp_year
# 198  2372.0  Bahamas1987  2,713,999,900
# Bahamas1993
# Bahamas1993
#       index country-year       gdp_year
# 199  2384.0  Bahamas1993  3,092,000,000
# Bahamas1994
# Bahamas1994
#       index country-year       gdp_year
# 200  2396.0  Bahamas1994  3,259,000,000
# Bahamas1995
# Bahamas1995
#       index country-year       gdp_year
# 201  2408.0  Bahamas1995  3,429,000,000
# Bahamas1996
# Bahamas1996
#       index country-year       gdp_year
# 202  2420.0  Bahamas1996  3,609,000,000
# Bahamas1997
# Bahamas1997
#       index country-year       gdp_year
# 203  2432.0  Bahamas1997  6,332,360,000
# Bahamas1998
# Bahamas1998
#       index country-year       gdp_year
# 204  2444.0  Bahamas1998  6,833,220,000
# Bahamas1999
# Bahamas1999
#       index country-year       gdp_year
# 205  2456.0  Bahamas1999  7,683,870,000
# Bahamas2000
# Bahamas2000
#       index country-year       gdp_year
# 206  2468.0  Bahamas2000  8,076,470,000
# Bahamas2001
# Bahamas2001
#       index country-year       gdp_year
# 207  2480.0  Bahamas2001  8,317,830,000
# Bahamas2002
# Bahamas2002
#       index country-year       gdp_year
# 208  2492.0  Bahamas2002  8,881,160,000
# Bahamas2003
# Bahamas2003
#       index country-year       gdp_year
# 209  2504.0  Bahamas2003  8,870,090,000
# Bahamas2004
# Bahamas2004
#       index country-year       gdp_year
# 210  2516.0  Bahamas2004  9,055,290,000
# Bahamas2005
# Bahamas2005
#       index country-year       gdp_year
# 211  2528.0  Bahamas2005  9,836,200,000
# Bahamas2006
# Bahamas2006
#       index country-year        gdp_year
# 212  2540.0  Bahamas2006  10,167,250,000
# Bahamas2007
# Bahamas2007
#       index country-year        gdp_year
# 213  2552.0  Bahamas2007  10,618,340,000
# Bahamas2008
# Bahamas2008
#       index country-year        gdp_year
# 214  2564.0  Bahamas2008  10,526,000,000
# Bahamas2009
# Bahamas2009
#       index country-year       gdp_year
# 215  2576.0  Bahamas2009  9,981,960,000
# Bahamas2010
# Bahamas2010
#       index country-year        gdp_year
# 216  2588.0  Bahamas2010  10,095,760,000
# Bahamas2011
# Bahamas2011
#       index country-year        gdp_year
# 217  2600.0  Bahamas2011  10,070,450,000
# Bahamas2012
# Bahamas2012
#       index country-year        gdp_year
# 218  2612.0  Bahamas2012  10,720,500,000
# Bahamas2013
# Bahamas2013
#       index country-year        gdp_year
# 219  2624.0  Bahamas2013  10,627,600,000
# Bahrain1985
# Bahrain1985
#       index country-year       gdp_year
# 220  2636.0  Bahrain1985  3,651,861,702
# Bahrain1987
# Bahrain1987
#       index country-year       gdp_year
# 221  2648.0  Bahrain1987  3,392,021,011
# Bahrain1988
# Bahrain1988
#       index country-year       gdp_year
# 222  2660.0  Bahrain1988  3,702,393,617
# Bahrain1997
# Bahrain1997
#       index country-year       gdp_year
# 223  2672.0  Bahrain1997  6,349,202,394
# Bahrain1998
# Bahrain1998
#       index country-year       gdp_year
# 224  2684.0  Bahrain1998  6,183,776,596
# Bahrain1999
# Bahrain1999
#       index country-year       gdp_year
# 225  2696.0  Bahrain1999  6,621,010,372
# Bahrain2000
# Bahrain2000
#       index country-year       gdp_year
# 226  2708.0  Bahrain2000  9,062,906,915
# Bahrain2001
# Bahrain2001
#       index country-year       gdp_year
# 227  2720.0  Bahrain2001  8,976,207,713
# Bahrain2002
# Bahrain2002
#       index country-year       gdp_year
# 228  2732.0  Bahrain2002  9,632,155,053
# Bahrain2003
# Bahrain2003
#       index country-year        gdp_year
# 229  2744.0  Bahrain2003  11,074,822,074
# Bahrain2004
# Bahrain2004
#       index country-year        gdp_year
# 230  2756.0  Bahrain2004  13,150,166,755
# Bahrain2005
# Bahrain2005
#       index country-year        gdp_year
# 259  3104.0  Barbados2007  4,523,750,000
# Barbados2008
# Barbados2008
#       index  country-year       gdp_year
# 260  3116.0  Barbados2008  4,607,300,000
# Barbados2009
# Barbados2009
#       index  country-year       gdp_year
# 261  3128.0  Barbados2009  4,434,050,000
# Barbados2010
# Barbados2010
#       index  country-year       gdp_year
# 262  3140.0  Barbados2010  4,461,650,000
# Barbados2011
# Barbados2011
#       index  country-year       gdp_year
# 263  3152.0  Barbados2011  4,660,900,000
# Barbados2012
# Barbados2012
#       index  country-year       gdp_year
# 264  3164.0  Barbados2012  4,656,350,000
# Barbados2013
# Barbados2013
#       index  country-year       gdp_year
# 265  3176.0  Barbados2013  4,612,500,000
# Belarus1990
# Belarus1990
#       index country-year        gdp_year
# 266  3188.0  Belarus1990  21,650,000,000
# Belarus1991
# Belarus1991
#       index country-year        gdp_year
# 267  3200.0  Belarus1991  18,000,000,000
# Belarus1992
# Belarus1992
#       index country-year        gdp_year
# 268  3212.0  Belarus1992  17,037,037,037
# Belarus1993
# Belarus1993
#       index country-year        gdp_year
# 269  3224.0  Belarus1993  16,280,991,736
# Belarus1994
# Belarus1994
#       index country-year        gdp_year
# 270  3236.0  Belarus1994  14,932,024,169
# Belarus1995
# Belarus1995
#       index country-year        gdp_year
# 271  3248.0  Belarus1995  13,972,676,841
# Belarus1996
# Belarus1996
#       index country-year        gdp_year
# 272  3260.0  Belarus1996  14,756,846,154
# Belarus1997
# Belarus1997
#       index country-year        gdp_year
# 273  3272.0  Belarus1997  14,128,408,566
# Belarus1998
# Belarus1998
#       index country-year        gdp_year
# 274  3284.0  Belarus1998  15,222,012,660
# Belarus1999
# Belarus1999
#       index country-year        gdp_year
# 275  3296.0  Belarus1999  12,138,486,532
# Belarus2000
# Belarus2000
#       index country-year        gdp_year
# 276  3308.0  Belarus2000  12,736,856,828
# Belarus2001
# Belarus2001
#       index country-year        gdp_year
# 277  3320.0  Belarus2001  12,354,820,144
# Belarus2002
# Belarus2002
#       index country-year        gdp_year
# 278  3332.0  Belarus2002  14,594,249,023
# Belarus2003
# Belarus2003
#       index country-year        gdp_year
# 279  3344.0  Belarus2003  17,827,791,321
# Belarus2007
# Belarus2007
#       index country-year        gdp_year
# 280  3356.0  Belarus2007  45,277,399,814
# Belarus2008
# Belarus2008
#       index country-year        gdp_year
# 281  3368.0  Belarus2008  60,763,483,146
# Belarus2009
# Belarus2009
#       index country-year        gdp_year
# 282  3380.0  Belarus2009  49,209,523,810
# Belarus2010
# Belarus2010
#       index country-year        gdp_year
# 283  3392.0  Belarus2010  57,222,490,769
# Belarus2011
# Belarus2011
#       index country-year        gdp_year
# 284  3404.0  Belarus2011  61,757,788,945
# Belarus2013
# Belarus2013
#       index country-year        gdp_year
# 285  3416.0  Belarus2013  75,527,984,234
# Belarus2014
# Belarus2014
#       index country-year        gdp_year
# 286  3428.0  Belarus2014  78,813,839,984
# Belgium1985
# Belgium1985
#       index country-year        gdp_year
# 287  3440.0  Belgium1985  86,730,038,793
# Belgium1986
# Belgium1986
#       index country-year         gdp_year
#       index country-year         gdp_year
# 317  3800.0  Belgium2015  455,039,563,133
# Belize1986
# Belize1986
#       index country-year     gdp_year
# 318  3812.0   Belize1986  227,850,000
# Belize1987
# Belize1987
#       index country-year     gdp_year
# 319  3824.0   Belize1987  276,550,000
# Belize1989
# Belize1989
#       index country-year     gdp_year
# 320  3836.0   Belize1989  363,150,000
# Belize1990
# Belize1990
#       index country-year     gdp_year
# 321  3848.0   Belize1990  413,050,000
# Belize1991
# Belize1991
#       index country-year     gdp_year
# 322  3860.0   Belize1991  444,720,750
# Belize1993
# Belize1993
#       index country-year     gdp_year
# 323  3872.0   Belize1993  559,858,250
# Belize1994
# Belize1994
#       index country-year     gdp_year
# 324  3884.0   Belize1994  580,863,700
# Belize1995
# Belize1995
#       index country-year     gdp_year
# 325  3896.0   Belize1995  620,140,400
# Belize1996
# Belize1996
#       index country-year     gdp_year
# 326  3908.0   Belize1996  641,383,800
# Belize1997
# Belize1997
#       index country-year     gdp_year
# 327  3920.0   Belize1997  654,314,350
# Belize1998
# Belize1998
#       index country-year     gdp_year
# 328  3932.0   Belize1998  688,992,450
# Belize1999
# Belize1999
#       index country-year     gdp_year
# 329  3944.0   Belize1999  732,732,350
# Belize2000
# Belize2000
#       index country-year     gdp_year
# 330  3956.0   Belize2000  832,072,450
# Belize2001
# Belize2001
#       index country-year     gdp_year
# 331  3968.0   Belize2001  871,860,600
# Belize2002
# Belize2002
#       index country-year     gdp_year
# 332  3980.0   Belize2002  932,551,850
# Belize2003
# Belize2003
#       index country-year     gdp_year
# 333  3992.0   Belize2003  990,374,050
# Belize2004
# Belize2004
#       index country-year       gdp_year
# 334  4004.0   Belize2004  1,057,845,500
# Belize2005
# Belize2005
#       index country-year       gdp_year
# 335  4016.0   Belize2005  1,114,222,550
# Belize2006
# Belize2006
#       index country-year       gdp_year
# 336  4028.0   Belize2006  1,217,467,600
# Belize2007
# Belize2007
#       index country-year       gdp_year
# 337  4040.0   Belize2007  1,290,573,400
# Belize2008
# Belize2008
#       index country-year       gdp_year
# 338  4052.0   Belize2008  1,368,625,150
# Belize2009
# Belize2009
#       index country-year       gdp_year
# 339  4064.0   Belize2009  1,336,957,250
# Belize2010
# Belize2010
#       index country-year       gdp_year
# 340  4076.0   Belize2010  1,397,113,450
# Belize2011
# Belize2011
#       index country-year       gdp_year
# 341  4088.0   Belize2011  1,487,005,600
# Belize2012
# Belize2012
#       index country-year       gdp_year
# 342  4100.0   Belize2012  1,573,670,250
# Belize2013
# Belize2013
#       index country-year       gdp_year
# 343  4112.0   Belize2013  1,612,573,850
# Belize2014
# Belize2014
#       index country-year       gdp_year
# 344  4124.0   Belize2014  1,703,951,050
# Belize2015
# Belize2015
#       index country-year       gdp_year
# 345  4136.0   Belize2015  1,778,567,600
# Bosnia and Herzegovina2011
# Bosnia and Herzegovina2011
#       index                country-year        gdp_year
# 346  4148.0  Bosnia and Herzegovina2011  18,644,723,861
# Bosnia and Herzegovina2014
# Bosnia and Herzegovina2014
#       index                country-year        gdp_year
# 347  4160.0  Bosnia and Herzegovina2014  18,558,343,508
# Brazil1985
# Brazil1985
#       index country-year         gdp_year
# 348  4172.0   Brazil1985  222,942,790,435
# Brazil1986
# Brazil1986
#       index country-year         gdp_year
# 349  4184.0   Brazil1986  268,137,224,730
# Brazil1987
# Brazil1987
#       index country-year         gdp_year
# 350  4196.0   Brazil1987  294,084,112,393
# Brazil1988
# Brazil1988
#       index country-year         gdp_year
# 351  4208.0   Brazil1988  330,397,381,998
# Brazil1989
# Brazil1989
#       index country-year         gdp_year
# 352  4220.0   Brazil1989  425,595,310,000
# Brazil1990
# Brazil1990
#       index country-year         gdp_year
# 353  4232.0   Brazil1990  461,951,782,000
# Brazil1991
# Brazil1991
#       index country-year         gdp_year
# 354  4244.0   Brazil1991  602,860,000,000
# Brazil1992
# Brazil1992
#       index country-year         gdp_year
# 355  4256.0   Brazil1992  400,599,250,000
# Brazil1993
# Brazil1993
#       index country-year         gdp_year
# 356  4268.0   Brazil1993  437,798,577,640
# Brazil1994
# Brazil1994
#       index country-year         gdp_year
# 357  4280.0   Brazil1994  558,111,997,497
# Brazil1995
# Brazil1995
#       index country-year         gdp_year
# 358  4292.0   Brazil1995  769,305,386,183
# Brazil1996
# Brazil1996
#       index country-year         gdp_year
# 359  4304.0   Brazil1996  850,426,432,992
# Brazil1997
# Brazil1997
#       index country-year         gdp_year
# 360  4316.0   Brazil1997  883,199,625,325
# Brazil1998
# Brazil1998
#       index country-year         gdp_year
# 361  4328.0   Brazil1998  863,723,411,633
# Brazil1999
# Brazil1999
#       index country-year         gdp_year
# 362  4340.0   Brazil1999  599,388,579,986
# Brazil2000
# Brazil2000
#       index country-year         gdp_year
# 363  4352.0   Brazil2000  655,420,645,477
# Brazil2001
# Brazil2001
#       index country-year         gdp_year
# 364  4364.0   Brazil2001  559,372,276,082
# Brazil2002
# Brazil2002
#       index country-year         gdp_year
# 365  4376.0   Brazil2002  507,962,487,700
# Brazil2003
# Brazil2003
#       index country-year         gdp_year
# 366  4388.0   Brazil2003  558,319,920,832
# Brazil2004
# Brazil2004
#       index country-year         gdp_year
# 367  4400.0   Brazil2004  669,316,654,017
# Brazil2005
# Brazil2005
#       index country-year         gdp_year
# 368  4412.0   Brazil2005  891,630,175,813
# Brazil2006
# Brazil2006
#       index country-year           gdp_year
# 369  4424.0   Brazil2006  1,107,640,297,890
# Brazil2007
# Brazil2007
#       index country-year           gdp_year
# 370  4436.0   Brazil2007  1,397,084,345,950
# Brazil2008
# Brazil2008
#       index country-year           gdp_year
# 371  4448.0   Brazil2008  1,695,824,571,927
# Brazil2009
# Brazil2009
#       index country-year           gdp_year
# 372  4460.0   Brazil2009  1,667,019,780,934
# Brazil2010
# Brazil2010
#       index country-year           gdp_year
# 373  4472.0   Brazil2010  2,208,871,646,203
# Brazil2011
# Brazil2011
#       index country-year           gdp_year
# 374  4484.0   Brazil2011  2,616,201,578,192
# Brazil2012
# Brazil2012
#       index country-year           gdp_year
# 375  4496.0   Brazil2012  2,465,188,674,415
# Brazil2013
# Brazil2013
#       index country-year           gdp_year
# 376  4508.0   Brazil2013  2,472,806,919,902
# Brazil2014
# Brazil2014
#       index country-year           gdp_year
# 377  4520.0   Brazil2014  2,455,993,625,159
# Brazil2015
# Brazil2015
#       index country-year           gdp_year
# 378  4532.0   Brazil2015  1,802,214,373,741
# Bulgaria1985
# Bulgaria1985
#       index  country-year        gdp_year
# 379  4544.0  Bulgaria1985  17,155,421,053
# Bulgaria1986
# Bulgaria1986
#       index  country-year        gdp_year
# 380  4556.0  Bulgaria1986  20,249,294,118
# Bulgaria1987
# Bulgaria1987
#       index  country-year        gdp_year
# 381  4568.0  Bulgaria1987  28,101,000,000
# Bulgaria1988
# Bulgaria1988
#       index  country-year        gdp_year
# 382  4580.0  Bulgaria1988  22,555,941,176
# Bulgaria1989
# Bulgaria1989
#       index  country-year        gdp_year
# 383  4592.0  Bulgaria1989  21,988,444,444
# Bulgaria1990
# Bulgaria1990
#       index  country-year        gdp_year
# 384  4604.0  Bulgaria1990  20,632,090,909
# Bulgaria1991
# Bulgaria1991
#       index  country-year        gdp_year
# 385  4616.0  Bulgaria1991  10,943,548,387
# Bulgaria1992
# Bulgaria1992
#       index  country-year        gdp_year
# 386  4628.0  Bulgaria1992  10,350,515,464
# Bulgaria1993
# Bulgaria1993
#       index  country-year        gdp_year
# 387  4640.0  Bulgaria1993  10,829,710,145
# Bulgaria1994
# Bulgaria1994
#       index  country-year       gdp_year
# 388  4652.0  Bulgaria1994  9,697,416,974
# Bulgaria1995
# Bulgaria1995
#       index  country-year        gdp_year
# 389  4664.0  Bulgaria1995  13,063,422,619
# Bulgaria1996
# Bulgaria1996
#       index  country-year        gdp_year
# 390  4676.0  Bulgaria1996  10,109,612,142
# Bulgaria1997
# Bulgaria1997
#       index  country-year        gdp_year
# 391  4688.0  Bulgaria1997  11,195,612,105
# Bulgaria1998
# Bulgaria1998
#       index  country-year        gdp_year
# 392  4700.0  Bulgaria1998  14,630,992,956
# Bulgaria1999
# Bulgaria1999
#       index  country-year        gdp_year
# 393  4712.0  Bulgaria1999  13,495,075,366
# Bulgaria2000
# Bulgaria2000
#       index  country-year        gdp_year
# 394  4724.0  Bulgaria2000  13,153,016,531
# Bulgaria2001
# Bulgaria2001
#       index  country-year        gdp_year
# 395  4736.0  Bulgaria2001  14,075,616,789
# Bulgaria2002
# Bulgaria2002
#       index  country-year        gdp_year
# 396  4748.0  Bulgaria2002  16,276,456,428
# Bulgaria2003
# Bulgaria2003
#       index  country-year        gdp_year
# 397  4760.0  Bulgaria2003  20,982,685,981
# Bulgaria2004
# Bulgaria2004
#       index  country-year        gdp_year
# 398  4772.0  Bulgaria2004  25,957,970,922
# Bulgaria2005
# Bulgaria2005
#       index  country-year        gdp_year
# 399  4784.0  Bulgaria2005  29,636,617,750
# Bulgaria2006
# Bulgaria2006
#       index  country-year        gdp_year
# 400  4796.0  Bulgaria2006  34,130,122,491
# Bulgaria2007
# Bulgaria2007
#       index  country-year        gdp_year
# 401  4808.0  Bulgaria2007  44,411,476,557
# Bulgaria2008
# Bulgaria2008
#       index  country-year        gdp_year
# 402  4820.0  Bulgaria2008  54,409,138,498
# Bulgaria2009
# Bulgaria2009
#       index  country-year        gdp_year
# 403  4832.0  Bulgaria2009  51,884,481,410
# Bulgaria2010
# Bulgaria2010
#       index  country-year        gdp_year
# 404  4844.0  Bulgaria2010  50,610,058,210
# Bulgaria2011
# Bulgaria2011
#       index  country-year        gdp_year
# 405  4856.0  Bulgaria2011  57,418,414,504
# Bulgaria2012
# Bulgaria2012
#       index  country-year        gdp_year
# 406  4868.0  Bulgaria2012  53,903,022,339
# Bulgaria2013
# Bulgaria2013
#       index  country-year        gdp_year
# 407  4880.0  Bulgaria2013  55,758,754,072
# Bulgaria2014
# Bulgaria2014
#       index  country-year        gdp_year
# 408  4892.0  Bulgaria2014  56,731,990,232
# Cabo Verde2011
# Cabo Verde2011
#       index    country-year       gdp_year
# 409  4904.0  Cabo Verde2011  1,864,824,081
# Canada1985
# Canada1985
#       index country-year         gdp_year
# 410  4916.0   Canada1985  364,756,499,451
# Canada1986
# Canada1986
#       index country-year         gdp_year
# 411  4928.0   Canada1986  377,437,927,312
# Canada1987
# Canada1987
#       index country-year         gdp_year
# 412  4940.0   Canada1987  431,316,742,081
# Canada1988
# Canada1988
#       index country-year         gdp_year
# 413  4952.0   Canada1988  507,354,351,182
# Canada1989
# Canada1989
#       index country-year         gdp_year
# 414  4964.0   Canada1989  565,055,743,243
# Canada1990
# Canada1990
#       index country-year         gdp_year
# 415  4976.0   Canada1990  593,929,550,908
# Canada1991
# Canada1991
#       index country-year         gdp_year
# 416  4988.0   Canada1991  610,328,183,643
# Canada1992
# Canada1992
#       index country-year         gdp_year
# 417  5000.0   Canada1992  592,387,689,253
# Canada1993
# Canada1993
#       index country-year         gdp_year
# 418  5012.0   Canada1993  577,170,761,956
# Canada1994
# Canada1994
#       index country-year         gdp_year
# 419  5024.0   Canada1994  578,139,279,438
# Canada1995
# Canada1995
#       index country-year         gdp_year
# 420  5036.0   Canada1995  604,031,623,433
# Canada1996
# Canada1996
#       index country-year         gdp_year
# 421  5048.0   Canada1996  628,546,387,972
# Canada1997
# Canada1997
#       index country-year         gdp_year
# 422  5060.0   Canada1997  652,825,364,726
# Canada1998
# Canada1998
#       index country-year         gdp_year
# 423  5072.0   Canada1998  631,813,279,407
# Canada1999
# Canada1999
#       index country-year         gdp_year
# 424  5084.0   Canada1999  676,082,654,641
# Canada2000
# Canada2000
#       index country-year         gdp_year
# 425  5096.0   Canada2000  742,293,448,253
# Canada2001
# Canada2001
#       index country-year         gdp_year
# 426  5108.0   Canada2001  736,379,777,893
# Canada2002
# Canada2002
#       index country-year         gdp_year
# 427  5120.0   Canada2002  757,950,678,647
# Canada2003
# Canada2003
#       index country-year         gdp_year
# 428  5132.0   Canada2003  892,380,986,368
# Canada2004
# Canada2004
#       index country-year           gdp_year
# 429  5144.0   Canada2004  1,023,196,003,075
# Canada2005
# Canada2005
#       index country-year           gdp_year
# 430  5156.0   Canada2005  1,169,357,979,865
# Uruguay1994
#         index country-year        gdp_year
# 2278  27304.0  Uruguay1994  17,474,647,792
# Uruguay1995
# Uruguay1995
#         index country-year        gdp_year
# 2279  27316.0  Uruguay1995  19,297,663,097
# Uruguay1996
# Uruguay1996
#         index country-year        gdp_year
# 2280  27328.0  Uruguay1996  20,515,543,039
# Uruguay1997
# Uruguay1997
#         index country-year        gdp_year
# 2281  27340.0  Uruguay1997  23,969,823,010
# Uruguay1998
# Uruguay1998
#         index country-year        gdp_year
# 2282  27352.0  Uruguay1998  25,385,928,198
# Uruguay1999
# Uruguay1999
#         index country-year        gdp_year
# 2283  27364.0  Uruguay1999  23,983,945,191
# Uruguay2000
# Uruguay2000
#         index country-year        gdp_year
# 2284  27376.0  Uruguay2000  22,823,255,802
# Uruguay2001
# Uruguay2001
#         index country-year        gdp_year
# 2285  27388.0  Uruguay2001  20,898,788,417
# Uruguay2002
# Uruguay2002
#         index country-year        gdp_year
# 2286  27400.0  Uruguay2002  13,606,494,599
# Uruguay2003
# Uruguay2003
#         index country-year        gdp_year
# 2287  27412.0  Uruguay2003  12,045,631,093
# Uruguay2004
# Uruguay2004
#         index country-year        gdp_year
# 2288  27424.0  Uruguay2004  13,686,329,890
# Uruguay2005
# Uruguay2005
#         index country-year        gdp_year
# 2289  27436.0  Uruguay2005  17,362,857,684
# Uruguay2006
# Uruguay2006
#         index country-year        gdp_year
# 2290  27448.0  Uruguay2006  19,579,457,966
# Uruguay2007
# Uruguay2007
#         index country-year        gdp_year
# 2291  27460.0  Uruguay2007  23,410,572,634
# Uruguay2008
# Uruguay2008
#         index country-year        gdp_year
# 2292  27472.0  Uruguay2008  30,366,213,119
# Uruguay2009
# Uruguay2009
#         index country-year        gdp_year
# 2293  27484.0  Uruguay2009  31,660,911,277
# Uruguay2010
# Uruguay2010
#         index country-year        gdp_year
# 2294  27496.0  Uruguay2010  40,284,481,652
# Uruguay2012
# Uruguay2012
#         index country-year        gdp_year
# 2295  27508.0  Uruguay2012  51,264,390,116
# Uruguay2013
# Uruguay2013
#         index country-year        gdp_year
# 2296  27520.0  Uruguay2013  57,531,233,351
# Uruguay2014
# Uruguay2014
#         index country-year        gdp_year
# 2297  27532.0  Uruguay2014  57,236,013,086
# Uruguay2015
# Uruguay2015
#         index country-year        gdp_year
# 2298  27544.0  Uruguay2015  53,274,304,222
# Uzbekistan1990
# Uzbekistan1990
#         index    country-year        gdp_year
# 2299  27556.0  Uzbekistan1990  13,360,607,918
# Uzbekistan1991
# Uzbekistan1991
#         index    country-year        gdp_year
# 2300  27568.0  Uzbekistan1991  13,677,622,222
# Uzbekistan1992
# Uzbekistan1992
#         index    country-year        gdp_year
# 2301  27580.0  Uzbekistan1992  12,941,297,376
# Uzbekistan1993
# Uzbekistan1993
#         index    country-year        gdp_year
# 2302  27592.0  Uzbekistan1993  13,099,013,836
# Uzbekistan1994
# Uzbekistan1994
#         index    country-year        gdp_year
# 2303  27604.0  Uzbekistan1994  12,899,156,991
# Uzbekistan1995
# Uzbekistan1995
# %%
df2_fin['suicide/100k'].describe()
df2_fin['suicide/100k'].plot.hist(bins=25)
plt.title('Distribution of Suicides per 100k for all countries between 1985 and 2015')
f2 = plt.gcf()

# %% [markdown]
# The above graph highlights the frequency of suicides per year for all the countries in the dataset. The suicide rate for most years per country is less than 20 per 100k, with the highest suicide rate reaching ~50 per 100k, and the lowest being ~0 per 100k. However, this distribution has a strong right-skew, which means that the mean wil be higher than the median. The highest suicide rate frequency is present ~8 per 100k.

# %%
#no neg values, possible to have 0 suicides, min value for gdp is reasonable, no more cleaning. 
#continue analyses
desc = df2_fin.describe()
desc
# Out:
#               year   suicides_no    population  suicide/100k      gdp_year
# count  2321.000000   2321.000000  2.321000e+03   2321.000000  2.321000e+03
# mean   2001.275312   2907.548470  2.211209e+07     11.738663  4.452791e+11
# std       8.480583   7077.828004  4.167543e+07      8.921654  1.453108e+12
# min    1985.000000      0.000000  2.519200e+04      0.000000  4.691962e+07
# 25%    1995.000000    118.000000  1.996086e+06      4.998151  8.992642e+09
# 50%    2002.000000    565.000000  5.360200e+06     10.083301  4.811469e+10
# 75%    2008.000000   2247.000000  2.056996e+07     16.146591  2.602024e+11
# max    2016.000000  61420.000000  3.000785e+08     51.019758  1.812071e+13

# %%
#finding low-tier countries based on gdp
df2_test = df2_suicide_reset.groupby(['country','year']).sum()
df2_test = df2_test.reset_index()
df2_test = df2_test.set_index('country')
pd.set_option('display.max_rows',2000)
df2_test.sort_values(by=['gdp_year'])

df2_lowest = df2_test.loc[['Kiribati','Grenada','Saint Vincent and Grenadines']]
df2_lowest.head()
# Out:
#           year  suicides_no  population  suicide/100k  gdp_year
# country
# Kiribati  1991           10       61855     16.166842  47515189
# Kiribati  1992            4       62856      6.363752  47737955
# Kiribati  1993           12       63848     18.794637  46919625
# Kiribati  1994           10       64871     15.415209  54832578
# Kiribati  1995            2       65923      3.033843  56338028

# %%
plt.figure(figsize=(10,6))
kb = plt.scatter(df2_test.loc['Kiribati']['year'],df2_test.loc['Kiribati']['gdp_year'],alpha=1)
gr = plt.scatter(df2_test.loc['Grenada']['year'],df2_test.loc['Grenada']['gdp_year'])
svg = plt.scatter(df2_test.loc['Saint Vincent and Grenadines']['year'],df2_test.loc['Saint Vincent and Grenadines']['gdp_year'])
fit = np.polyfit(df2_lowest['year'], df2_lowest['gdp_year'],1)
plt.plot(df2_lowest['year'],fit[0]*df2_lowest['year']+fit[1],color='red')
plt.legend((kb,gr,svg),("Kiribati","Grenada","Saint Vincent and Grenadines"))
plt.title('GDP for low-tier countries between 1985 to 2015')

plt.xlabel('Year');
plt.ylabel('GDP ($)');

plt.figure(figsize=(10,6))
plt.scatter(df2_test.loc['Kiribati']['year'],df2_test.loc['Kiribati']['suicide/100k'],alpha=1)
plt.scatter(df2_test.loc['Grenada']['year'],df2_test.loc['Grenada']['suicide/100k'])
plt.scatter(df2_test.loc['Saint Vincent and Grenadines']['year'],df2_test.loc['Saint Vincent and Grenadines']['suicide/100k'])
fit1 = np.polyfit(df2_lowest['year'], df2_lowest['suicide/100k'],1)
plt.plot(df2_lowest['year'],fit1[0]*df2_lowest['year']+fit1[1],color='red')
plt.title('Number of suicides per 100k for low-tier countries between 1985 to 2015')
plt.legend((kb,gr,svg),("Kiribati","Grenada","Saint Vincent and Grenadines"))
plt.xlabel('Year');
plt.ylabel('Number of suicides per 100k');
#plt.xticks(np.arange(1e10,1.5e13,step=1e11))

#lowest 3 : Kiribati, Saint Vincent and Grenadines, Grenada
#highest 3: US, Japan, Germany
#middle 3: Slovakia, Slovenia, Serbia

# %% [markdown]
# The above graphs show a negative correlation between GDP and number of suicides per 100k in countries with a low GDP by comparing the slopes of the best-fit lines found in the two graphs. In the first graph, it is evident that the GDP for countries with a lower GDP increases over time. While the second graph illustrates that the suicide rate for these countries decreases over the same time period found in the first graph.

# %%
df2_mid = df2_test.loc[['Slovenia','Slovakia','Serbia']]
plt.figure(figsize=(10,6))
sv = plt.scatter(df2_test.loc['Slovakia']['year'],df2_test.loc['Slovakia']['gdp_year'],alpha=1)
sl = plt.scatter(df2_test.loc['Slovenia']['year'],df2_test.loc['Slovenia']['gdp_year'])
sb = plt.scatter(df2_test.loc['Serbia']['year'],df2_test.loc['Serbia']['gdp_year'])
fit = np.polyfit(df2_mid['year'], df2_mid['gdp_year'],1)
plt.plot(df2_mid['year'],fit[0]*df2_mid['year']+fit[1],color='red')
plt.legend((sv,sl,sb),("Slovakia","Slovenia","Serbia"))
plt.title('GDP for mid-tier countries between 1985 to 2015')
plt.xlabel('Year');
plt.ylabel('GDP ($)');

plt.figure(figsize=(10,6))
sv = plt.scatter(df2_test.loc['Slovakia']['year'],df2_test.loc['Slovakia']['suicide/100k'],alpha=1)
sl = plt.scatter(df2_test.loc['Slovenia']['year'],df2_test.loc['Slovenia']['suicide/100k'])
sb = plt.scatter(df2_test.loc['Serbia']['year'],df2_test.loc['Serbia']['suicide/100k'])
fit = np.polyfit(df2_mid['year'], df2_mid['suicide/100k'],1)
plt.plot(df2_mid['year'],fit[0]*df2_mid['year']+fit[1],color='red')
plt.title('Number of suicides per 100k for mid-tier countries between 1985 to 2015')
plt.legend((sv,sl,sb),("Slovakia","Slovenia","Serbia"))
plt.xlabel('Year');
plt.ylabel('Number of suicides per 100k');

# %% [markdown]
# The above graphs show a weak negative correlation between GDP over time and number of suicides per 100k over time for countries with a average GDP comapared to the rest of the countries found in the dataset. The first graph, illustrates that the chosen countries had an steady increase in GDP from 1985 to 2015. While the second graph highlights the fact that during the same time period, there was a slight decrease of suicides per year. By comparing the bestfit lines found in both graphs, there is evidence that there is a weak negative correlation between GDP and suicide rate.

# %%
df2_high = df2_test.loc[['United States','Japan','Germany']]

plt.figure(figsize=(10,6))
us = plt.scatter(df2_test.loc['United States']['year'],df2_test.loc['United States']['gdp_year'],alpha=1)
jp = plt.scatter(df2_test.loc['Japan']['year'],df2_test.loc['Japan']['gdp_year'])
gm = plt.scatter(df2_test.loc['Germany']['year'],df2_test.loc['Germany']['gdp_year'])
fit = np.polyfit(df2_high['year'], df2_high['gdp_year'],1)
plt.plot(df2_high['year'],fit[0]*df2_high['year']+fit[1],color='red')
plt.legend((us,jp,gm),("United States","Japan","Germany"))
plt.title('GDP for high-tier countries between 1985 to 2015')
plt.xlabel('Year');
plt.ylabel('GDP ($)');

plt.figure(figsize=(10,6))
sv = plt.scatter(df2_test.loc['United States']['year'],df2_test.loc['United States']['suicide/100k'],alpha=1)
sl = plt.scatter(df2_test.loc['Japan']['year'],df2_test.loc['Japan']['suicide/100k'])
sb = plt.scatter(df2_test.loc['Germany']['year'],df2_test.loc['Germany']['suicide/100k'])
fit = np.polyfit(df2_high['year'], df2_high['suicide/100k'],1)
plt.plot(df2_high['year'],fit[0]*df2_high['year']+fit[1],color='red')
plt.title('Number of suicides per 100k for high-tier countries between 1985 to 2015')
plt.legend((us,jp,gm),("United States","Japan","Germany"))
plt.xlabel('Year');
plt.ylabel('Number of suicides per 100k');

# %% [markdown]
# The above graphs measure GDP over time and and number of suicides per 100k over the same time period for countries with a large GDP value. In the first graph, it is evident that all three countries had a steady increase in GDP over time. While the second graph for suicides over time does not show a steady pattern throughout the years. Therefore, the bestfit line for the second graph is very horizontal and we cannot conlude that a higher GDP correlates to a lower suicide rate.

# %%
plt.figure(figsize=(10,6))
sv = plt.scatter(df2_test.loc['United States']['year'],df2_test.loc['United States']['suicide/100k'],alpha=1)
fit = np.polyfit(df2_high.loc['United States']['year'], df2_high.loc['United States']['suicide/100k'],1)
plt.plot(df2_high.loc['United States']['year'],fit[0]*df2_high.loc['United States']['year']+fit[1],color='red')
plt.title('Number of suicides per 100k for United States between 1985 to 2015')
plt.xlabel('Year');
plt.ylabel('Number of suicides per 100k');


plt.figure(figsize=(10,6))
sv = plt.scatter(df2_test.loc['Japan']['year'],df2_test.loc['Japan']['suicide/100k'],alpha=1,color='orange')
fit = np.polyfit(df2_high.loc['Japan']['year'], df2_high.loc['Japan']['suicide/100k'],1)
plt.plot(df2_high.loc['Japan']['year'],fit[0]*df2_high.loc['Japan']['year']+fit[1],color='red')
plt.title('Number of suicides per 100k for Japan between 1985 to 2015')
plt.xlabel('Year');
plt.ylabel('Number of suicides per 100k');

plt.figure(figsize=(10,6))
sv = plt.scatter(df2_test.loc['Germany']['year'],df2_test.loc['Germany']['suicide/100k'],alpha=1,color='green')
fit = np.polyfit(df2_high.loc['Germany']['year'], df2_high.loc['Germany']['suicide/100k'],1)
plt.plot(df2_high.loc['Germany']['year'],fit[0]*df2_high.loc['Germany']['year']+fit[1],color='red')
plt.title('Number of suicides per 100k for Germany between 1990 to 2015')
plt.xlabel('Year');
plt.ylabel('Number of suicides per 100k');

# %% [markdown]
# For the three graphs above, we decided to split up the countries found in the number of suicides per 100k for high-tier countries. This is due to the fact, that the values presented in the graph varied a lot for each country. The first graph, compares the suicide rate over time for the United States. This bestfit line had a slight positive slope, which corresponds to a positive correlation to the rise of GDP. The second graph compares the suicide rate for Japan, which also had a positive slope for the bestfit line. Lastly, the third graph illustrates the number of suicides over time for Germany. This had a bestfit line with a negative slope, which corresponds to a strong negative correlation to the rise of their GDP.

# %%
#calculate pairwise correlation between all vars
corrs = df2_fin.corr()
corrs
#the two highest correlates for suicide_rate are suicides_no and log(gdp)
#population and suicides_no, as well as population and gdp_year are highly correlated
# Out:
#                   year  suicides_no  population  suicide/100k  gdp_year
# year          1.000000    -0.007759    0.008887     -0.015713  0.094001
# suicides_no  -0.007759     1.000000    0.808095      0.360253  0.657589
# population    0.008887     0.808095    1.000000      0.083918  0.800281
# suicide/100k -0.015713     0.360253    0.083918      1.000000  0.071868
# gdp_year      0.094001     0.657589    0.800281      0.071868  1.000000

# %%
plt.scatter(df2_fin['gdp_year'],df2_fin['suicide/100k'],s=20)
plt.xlabel('gdp')
plt.ylabel('suicide/100k')
# Out:
# Text(0, 0.5, 'suicide/100k')

# %% [markdown]
# The above graph highlights the GDP per year versus the suicide rate per 100k for that given year. The graph shows that countries with a GDP on the lower end of the x-axis with a GDP less than 200 billion has a wide range of suicides per 100k. While the suicide rate flat-lines once the GDP reached above ~7 trillion.

# %%
#predictions
df2_fin.columns = ['country','year','suicides_no','population','suicideper100','country-year','gdp_year']
a1, b1 = np.polyfit(df2_fin['gdp_year'],df2_fin['suicideper100'],1)

gdp = np.arange(1e8,2e13,1e10)
pred_gdp = np.array([],dtype=float)

for i in gdp:
    pred = a1 * i + b1
    pred_gdp = np.append(pred_gdp,pred)

plt.scatter(df2_fin['gdp_year'],df2_fin['suicideper100'],s=20)
plt.plot(gdp, pred_gdp, color='red')
plt.xlabel('gdp')
plt.ylabel('suicide/100k')


f5 = plt.gcf()

# %% [markdown]
# The above graph is the same graph that plots gdp versus suicide per 100k, however this graph includes a bestfit line which plots a positive correlation.

# %%
#linear model to assess significance of gdp as a predictor of suicide
outcome_1, predictors_1 = patsy.dmatrices('suicideper100 ~ gdp_year', df2_fin)
mod_1 = sm.OLS(outcome_1, predictors_1)
res_1 = mod_1.fit()

# %%
# Print out the summary results of the model fitting
print(res_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          suicideper100   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     12.04
# Date:                Sat, 08 Jun 2019   Prob (F-statistic):           0.000530
# Time:                        17:47:32   Log-Likelihood:                -8366.3
# No. Observations:                2321   AIC:                         1.674e+04
# Df Residuals:                    2319   BIC:                         1.675e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.5422      0.193     59.733      0.000      11.163      11.921
# gdp_year    4.412e-13   1.27e-13      3.470      0.001    1.92e-13    6.91e-13
# ==============================================================================
# Omnibus:                      423.061   Durbin-Watson:                   0.128
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              729.823
# Skew:                           1.168   Prob(JB):                    3.32e-159
# Kurtosis:                       4.446   Cond. No.                     1.59e+12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#using alpha=0.01, we reject the null hypothesis so gdp per year significantly predicts suicide per 100k.

# %% [markdown]
# # Ethics and Privacy
# For the dataset chosen to be analyzed, there are not many privacy concerns, since the observations are based upon large populations rather than individuals. However, there are concerns about biases and potential prejudices since some of the countries included in the dataset have more complete data, and most of the countries are in the top-tier of the socioeconomic status spectrum. In addition, by providing a suicide rate value for a certain population based upon gender and age, people could develop a prejudice about that age group or gender that is not actually true.<br><br>
#
# In order to avoid this issue, we chose to analyze populations for entire countries, which include a larger age range and more than one gender. By doing so, we eliminate the possibility of people developing prejudices for certain age groups or genders.
